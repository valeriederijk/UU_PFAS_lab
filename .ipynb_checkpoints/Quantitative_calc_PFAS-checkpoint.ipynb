# %% [markdown]
# # Calculation of RSE and quantitative determination of PFAS concentrations from the LC-TQ
#
#
# Author: Valerie de Rijk
#
#
# Date: 15/8/2025

# %% [markdown]
# ## Data Loading
# We load in the data first. Please provide the (relative) directory of the folder

# %%
#data loading
import pandas as pd
import numpy as np
# Read the file to process headers
with open("rawdata/rawdatatrial.csv", 'r') as f:
    first_line = f.readline().strip().split(';')
    second_line = f.readline().strip().split(';')
    
# PFAS compounds from first line (skip 'Sample')
pfas_compounds = [name.replace(' Results', '') for name in first_line[1:] if 'Results' in name]
print("PFAS compounds:", pfas_compounds)

# Create combined headers
combined_headers = []
pfas_index = 0

for i, header in enumerate(second_line):
    # Keep the initial metadata columns as they are
    if header in ['Name', 'Data File', 'Type', 'Level', 'Acq. Date-Time']:
        combined_headers.append(header)
    # For RT, Final Conc., Accuracy, S/N - combine with PFAS name
    elif header in ['RT', 'Final Conc.', 'Accuracy', 'S/N']:
        if pfas_index < len(pfas_compounds):
            pfas_name = pfas_compounds[pfas_index]
            combined_headers.append(f"{pfas_name}_{header}")
            # Move to next PFAS compound after S/N (assuming each compound has RT, Final Conc., Accuracy, S/N)
            if header == 'S/N':
                pfas_index += 1
        else:
            combined_headers.append(header)
    else:
        combined_headers.append(header)

# Read the actual data (skip first 2 lines)
rawdata = pd.read_csv("rawdata/rawdatatrial.csv", delimiter=';', skiprows=2, header=None)

# Assign the combined headers (handle case where we might have more/fewer columns)
if len(combined_headers) <= len(rawdata.columns):
    rawdata.columns = combined_headers + [f"Extra_Col_{i}" for i in range(len(combined_headers), len(rawdata.columns))]
else:
    rawdata.columns = combined_headers[:len(rawdata.columns)]
# Out:
# PFAS compounds: ['13C4-PFBA', 'PFBA', '13C5-PFPeA', 'PFPeA', '4:2 FTS', '13C2-4:2FTS', '13C5-PFHxA', 'PFHxA', '13C3-PFBS', 'PFBS', '13C3-HFPO-DA', 'HFPO-DA', 'PFPHpA', '13C4-PFHpA', 'PFPeS', 'ADONA', '6:2 FTS', '13C2-6:2FTS', '13C8-PFOA', 'PFOA', 'PFHxS', '13C3-PFHxS', 'PFNA', '13C9-PFNA', 'PFHpS', '8:2 FTS', '13C2-8:2FTS', '13C6-PFDA', 'PFDA', 'D3-NMeFOSAA', 'NMeFOSAA', 'PFOS', '13C8-PFOS', 'D5-NEtFOSAA', 'NEtFOSAA', 'PFUnA', '13C7-PFUnA', '9Cl-PF3ONS', 'PFNS', 'PFDoA', '13C2-PFDoA', 'PFDS', 'PFTrDA', '11Cl-PF3OUdS', '13C2-PFTeDA', 'PFTeDA', 'PFOSA', '13C8-PFOSA', 'D7-NMeFOSE', 'NMeFOSE', 'NMeFOSA', 'D3-NMeFOSA', 'NEtFOSA', 'D9-NEtFOSE', 'NEtFOSE', 'D5-NEtFOSA']

# %% [markdown]
# ## Instrument linearity
# Now, we check the instrument linearity for the EIS and target analytes.
# First, we definte the formula for RSE based on EPA method 1633 (*section 10.3.3.3, page 28, option 2*)

# %%
import math

def calculate_rse(expected, measured, compound_name, p=2):
    """
    Calculate Relative Standard Error (RSE) for calibration data.
    If RSE > 20% for linear calibration (p=2), recalculate with p=3 (quadratic).
    
    Parameters:
    expected: list of expected/theoretical concentrations (xi)
    measured: list of measured concentrations (xi')
    compound_name: name of the compound for display
    p: number of parameters (default=2 for linear calibration: slope + intercept)
    
    Returns:
    dict with RSE results and detailed calculations
    """
    if len(expected) != len(measured):
        raise ValueError("Expected and measured arrays must have the same length")
    
    def compute_rse(expected, measured, p, compound_name):
        n = len(expected)
        sum_relative_squared_error = 0
        detailed_results = []
        
        print(f"\n{compound_name} (p={p})")
        print("="*60)
        print("Point\tExpected\tMeasured\tDifference\t(Diff)²/xi²\t(Diff)²/xi²/(n-p)")
        print("-" * 80)
        
        for i in range(n):
            diff = measured[i] - expected[i]
            nominator = (diff / expected[i]) ** 2
            relative_squared_error = nominator / (n - p)
            sum_relative_squared_error += relative_squared_error
            
            detailed_results.append({
                'Point': f'CAL {i+1}',
                'Expected': expected[i],
                'Measured': measured[i],
                'Difference': diff,
                'Nominator': nominator,
                'Relative_Squared_Error_Term': relative_squared_error
            })
            
            print(f"CAL {i+1}\t{expected[i]}\t\t{measured[i]:.4f}\t\t{diff:.4f}\t\t"
                  f"{nominator:.6f}\t{relative_squared_error:.6f}")
        
        rse = 100 * math.sqrt(sum_relative_squared_error)
        
        print("-" * 80)
        print(f"Sum of relative squared errors: {sum_relative_squared_error:.6f}")
        print(f"RSE = 100 * √({sum_relative_squared_error:.6f}) = {rse:.3f}%")
        
        return rse, detailed_results, sum_relative_squared_error
    
    # Step 1: Compute RSE with the given p (default=2 for linear)
    rse, details, sum_rse = compute_rse(expected, measured, p, compound_name)
    
    relationship_type = "linear" if p == 2 else "quadratic"
    
    # Step 2: If RSE > 20% and p was 2, redo with p=3
    if p == 2 and rse > 20:
        print("\nLinearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...")
        p = 3
        rse, details, sum_rse = compute_rse(expected, measured, p, compound_name)
        relationship_type = "quadratic"
    
    # Step 3: Return results
    return {
        'compound_name': compound_name,
        'n_points': len(expected),
        'parameters': p,
        'relationship_type': relationship_type,
        'rse_percent': rse,
        'sum_relative_squared_error': sum_rse,
        'detailed_results': details
    }

def calculate_eis_rse(df, expected_concentrations, p=2):
    """
    Calculate RSE (Relative Standard Error) for EIS compounds from PFAS data using specific RSE formula
    
    Parameters:
    df: DataFrame with PFAS data (with combined headers like '13C4-PFBA_Final Conc.')
    expected_concentrations: dict with EIS compound names and their single expected concentration
                           e.g., {'13C4-PFBA': 100.0, '13C5-PFPeA': 50.0, '13C2-4:2FTS': 25.0}
    p: number of parameters in calibration model (default=2 for linear: slope + intercept)
    
    Returns:
    Dictionary with RSE results for each EIS compound
    """
    
    # Define EIS compounds (those starting with numbers/isotope labels)
    eis_compounds = []
    for col in df.columns:
        if '_Final Conc.' in col:
            compound_name = col.replace('_Final Conc.', '')
            # Check if it's an EIS (starts with isotope labels like 13C, 18O, etc.)
            if any(compound_name.startswith(prefix) for prefix in ['13C', '18O', '15N', '2H', 'D']):
                eis_compounds.append(compound_name)
    
    print(f"Identified EIS compounds: {eis_compounds}")
    
    # Filter for CAL samples only
    cal_data = df[df['Type'] == 'Cal'].copy()
    
    if cal_data.empty:
        print("No CAL samples found in the data")
        return {}
    
    print(f"Found {len(cal_data)} CAL samples")
    
    rse_results_eis = {}
    
    for compound in eis_compounds:
        conc_col = f"{compound}_Final Conc."
        
        if conc_col not in df.columns:
            print(f"Warning: Column {conc_col} not found")
            continue
            
        if compound not in expected_concentrations:
            print(f"Warning: No expected concentrations provided for {compound}")
            continue
        
        # Get actual concentrations from CAL samples
        actual_concs = cal_data[conc_col].values
        expected_conc = expected_concentrations[compound]  # Single expected value
        
        # Remove any NaN values from actual concentrations
        valid_mask = ~np.isnan(actual_concs)
        actual_concs_clean = actual_concs[valid_mask]
        
        if len(actual_concs_clean) == 0:
            print(f"Warning: No valid data points for {compound}")
            continue
        
        # For EIS, all calibration points should have the same expected concentration
        expected_concs_list = [expected_conc] * len(actual_concs_clean)
        
        # Use the specific RSE calculation function
        rse_result = calculate_rse(expected_concs_list, actual_concs_clean.tolist(), compound, p)
        rse_results_eis[compound] = rse_result
    
    return rse_results_eis

def calculate_target_rse(df, expected_concentrations, p=2):
    """
    Calculate RSE (Relative Standard Error) for target analytes.
    """
    import numpy as np

    # Define target analytes
    target_analytes = []
    for col in df.columns:
        if '_Final Conc.' in col:
            compound_name = col.replace('_Final Conc.', '')
            if compound_name in expected_concentrations:
                target_analytes.append(compound_name)

    print(f"Identified target analytes: {target_analytes}")

    # Filter for CAL samples only
    cal_data = df[df['Type'] == 'Cal'].copy()
    if cal_data.empty:
        print("No CAL samples found in the data")
        return {}

    rse_results_eis = {}
    
    for compound in target_analytes:
        conc_col = f"{compound}_Final Conc."
        
        if conc_col not in df.columns:
            print(f"Warning: Column {conc_col} not found")
            continue
            
        if compound not in expected_concentrations:
            print(f"Warning: No expected concentrations provided for {compound}")
            continue
        
        # Actual concentrations from CAL samples
        actual_concs = cal_data[conc_col].values
        expected_list = np.array(expected_concentrations[compound], dtype=float)

        # Remove NaNs from actual concentrations *and* align expected list
        valid_mask = ~np.isnan(actual_concs)
        actual_concs_clean = actual_concs[valid_mask]
        expected_clean = expected_list[valid_mask]

        if len(actual_concs_clean) == 0:
            print(f"Warning: No valid data points for {compound}")
            continue
        
        # Use your existing RSE calculation function
        rse_result = calculate_rse(expected_clean.tolist(), 
                                   actual_concs_clean.tolist(), 
                                   compound, p)
        rse_results_target[compound] = rse_result
    
    return rse_results_target



    

def print_rse_summary(rse_results):
    """Print a formatted summary of RSE results"""
    print("\n" + "="*60)
    print("COMPOUND RSE SUMMARY")
    print("="*60)
    
    for compound, results in rse_results.items():
        print(f"\n{compound}:")
        print(f"  RSE: {results['rse_percent']:.3f}%")
        print(f"  Calibration Points: {results['n_points']}")
        print(f"  Relationship type: {results['relationship_type']} "
              f"(p = {results['parameters']})")
        
        if results['relationship_type'] == "quadratic" and results['rse_percent'] > 20:
            print("  ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — "
                  "system does not pass linearity or quadratic check.")
        elif results['relationship_type'] == "quadratic":
            print("  ✔ Note: Linear check failed, but quadratic fit passed RSE < 20%.")
        elif results['rse_percent'] > 20:
            print("  ⚠ WARNING: Linear fit (p=2) failed RSE > 20%. Quadratic check not run.")


# Define expected concentrations for each EIS compound (single value each)
expected_concs_EIS = {
    'D7-NMeFOSE': 25,     # still check
    'D9-NEtFOSE': 25,    
    '13C4-PFBA': 10, 
    '13C3-HFPO-DA': 10, 
    '13C5-PFPeA': 5, 
    '13C2-4:2FTS': 5, 
    '13C2-6:2FTS': 5, 
    '13C2-8:2FTS': 5, 
    'D3-NMeFOSAA': 5, 
    'D5-NEtFOSAA': 5, 
    '13C5-PFHxA': 2.5, 
    '13C4-PFPHpA': 2.5,
    '13C8-PFOA': 2.5,
    '13C3-PFBS': 2.5, 
    '13C3-PFHxS': 2.5,
    '13C8-PFOS': 2.5,
    '13C8-PFOSA': 2.5,
    'D3-NMeFOSA': 2.5,
    'D5-NEtFOSA': 2.5, 
    '13C6-PFDA': 1.25,
    '13C7-PFUnA': 1.25,
    '13C2-PFDoA': 1.25, 
    '13C2-PFTeDA': 1.25
} 
expected_target_conc_1 = [0.8, 2, 5, 10, 20, 50, 250] #ng/ml
expected_target_conc_2 = [2, 5, 12.5, 25, 50, 25, 625] #ng/ml
expected_target_conc_3 = [0.2, 0.5, 1.25, 2.5, 5, 12.5, 62.5] #ng/ml


expected_concs_target_analytes = {
    'PFBA': expected_target_conc_1, 
    '4:2 FTS': expected_target_conc_1,
    '6:2 FTS': expected_target_conc_1,
    '8:2 FTS': expected_target_conc_1,
    'HFPO-DA': expected_target_conc_1,
    'ADONA': expected_target_conc_1,
    '11Cl-PF3ONS': expected_target_conc_1,
    '9Cl-PF3ONS': expected_target_conc_1,
    'PFPeA': [0.4, 1, 2.5, 5, 10, 25, 125], 
    'NMeFOSE': expected_target_conc_2, 
    'NEtFOSE': expected_target_conc_2,
    'PFHxA' : expected_target_conc_3,
    'PFHpA' : expected_target_conc_3, 
    'PFOA' : expected_target_conc_3, 
    'PFNA': expected_target_conc_3,
    'PFDA': expected_target_conc_3, 
    'PFUnA': expected_target_conc_3,
    'PFDoA': expected_target_conc_3,
    'PFTrDA': expected_target_conc_3,
    'PFTeDA': expected_target_conc_3,
    'PFBS': expected_target_conc_3,
    'PFPeS': expected_target_conc_3,
    'PFHxS': expected_target_conc_3,
    'PFHpS': expected_target_conc_3,
    'PFOS': expected_target_conc_3,
    'PFOSA': expected_target_conc_3,
    'NMeFOSA': expected_target_conc_3,
    'NEtFOSA': expected_target_conc_3,
    'NMeFOSAA': expected_target_conc_3,
    'NEtFOSAA': expected_target_conc_3
}




# Calculate RSE for EIS compounds
rse_results_eis = calculate_eis_rse(rawdata, expected_concs_EIS)
rse_results_target = calculate_target_rse(rawdata, expected_concs_target_analytes)
# Print summary
print_rse_summary(rse_results_eis)
print_rse_summary(rse_results_target)
# Out:
# Identified EIS compounds: ['13C4-PFBA', '13C5-PFPeA', '13C2-4:2FTS', '13C5-PFHxA', '13C3-PFBS', '13C3-HFPO-DA', '13C4-PFHpA', '13C2-6:2FTS', '13C8-PFOA', '13C3-PFHxS', '13C9-PFNA', '13C2-8:2FTS', '13C6-PFDA', 'D3-NMeFOSAA', '13C8-PFOS', 'D5-NEtFOSAA', '13C7-PFUnA', '13C2-PFDoA', '13C2-PFTeDA', '13C8-PFOSA', 'D7-NMeFOSE', 'D3-NMeFOSA', 'D9-NEtFOSE', 'D5-NEtFOSA']
# Found 7 CAL samples
#
# 13C4-PFBA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	10		10.0412		0.0412		0.000017	0.000003
# CAL 2	10		9.9619		-0.0381		0.000015	0.000003
# CAL 3	10		9.9863		-0.0137		0.000002	0.000000
# CAL 4	10		9.9499		-0.0501		0.000025	0.000005
# CAL 5	10		9.9888		-0.0112		0.000001	0.000000
# CAL 6	10		10.0514		0.0514		0.000026	0.000005
# CAL 7	10		10.0204		0.0204		0.000004	0.000001
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.000018
# RSE = 100 * √(0.000018) = 0.425%
#
# 13C5-PFPeA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		4.8606		-0.1394		0.000777	0.000155
# CAL 2	5		5.0169		0.0169		0.000011	0.000002
# CAL 3	5		5.0886		0.0886		0.000314	0.000063
# CAL 4	5		5.0425		0.0425		0.000072	0.000014
# CAL 5	5		5.1151		0.1151		0.000530	0.000106
# CAL 6	5		5.0520		0.0520		0.000108	0.000022
# CAL 7	5		4.8242		-0.1758		0.001236	0.000247
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.000610
# RSE = 100 * √(0.000610) = 2.470%
#
# 13C2-4:2FTS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		3.2060		-1.7940		0.128737	0.025747
# CAL 2	5		3.5100		-1.4900		0.088804	0.017761
# CAL 3	5		3.5904		-1.4096		0.079479	0.015896
# CAL 4	5		3.8237		-1.1763		0.055347	0.011069
# CAL 5	5		4.1196		-0.8804		0.031004	0.006201
# CAL 6	5		5.2553		0.2553		0.002607	0.000521
# CAL 7	5		11.4952		6.4952		1.687505	0.337501
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.414697
# RSE = 100 * √(0.414697) = 64.397%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# 13C2-4:2FTS (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		3.2060		-1.7940		0.128737	0.032184
# CAL 2	5		3.5100		-1.4900		0.088804	0.022201
# CAL 3	5		3.5904		-1.4096		0.079479	0.019870
# CAL 4	5		3.8237		-1.1763		0.055347	0.013837
# CAL 5	5		4.1196		-0.8804		0.031004	0.007751
# CAL 6	5		5.2553		0.2553		0.002607	0.000652
# CAL 7	5		11.4952		6.4952		1.687505	0.421876
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.518371
# RSE = 100 * √(0.518371) = 71.998%
#
# 13C5-PFHxA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.4956		-0.0044		0.000003	0.000001
# CAL 2	2.5		2.5067		0.0067		0.000007	0.000001
# CAL 3	2.5		2.5011		0.0011		0.000000	0.000000
# CAL 4	2.5		2.5070		0.0070		0.000008	0.000002
# CAL 5	2.5		2.5038		0.0038		0.000002	0.000000
# CAL 6	2.5		2.4784		-0.0216		0.000075	0.000015
# CAL 7	2.5		2.5073		0.0073		0.000009	0.000002
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.000021
# RSE = 100 * √(0.000021) = 0.456%
#
# 13C3-PFBS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.5192		0.0192		0.000059	0.000012
# CAL 2	2.5		2.5399		0.0399		0.000255	0.000051
# CAL 3	2.5		2.5731		0.0731		0.000855	0.000171
# CAL 4	2.5		2.5596		0.0596		0.000568	0.000114
# CAL 5	2.5		2.5939		0.0939		0.001411	0.000282
# CAL 6	2.5		2.5190		0.0190		0.000058	0.000012
# CAL 7	2.5		2.1954		-0.3046		0.014845	0.002969
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.003610
# RSE = 100 * √(0.003610) = 6.008%
#
# 13C3-HFPO-DA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	10		10.4375		0.4375		0.001914	0.000383
# CAL 2	10		10.4051		0.4051		0.001641	0.000328
# CAL 3	10		10.3788		0.3788		0.001435	0.000287
# CAL 4	10		10.0241		0.0241		0.000006	0.000001
# CAL 5	10		9.9880		-0.0120		0.000001	0.000000
# CAL 6	10		10.0026		0.0026		0.000000	0.000000
# CAL 7	10		8.7638		-1.2362		0.015282	0.003056
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004056
# RSE = 100 * √(0.004056) = 6.369%
# Warning: No expected concentrations provided for 13C4-PFHpA
#
# 13C2-6:2FTS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		3.2275		-1.7725		0.125670	0.025134
# CAL 2	5		3.6542		-1.3458		0.072447	0.014489
# CAL 3	5		3.8056		-1.1944		0.057064	0.011413
# CAL 4	5		3.9283		-1.0717		0.045942	0.009188
# CAL 5	5		4.1861		-0.8139		0.026497	0.005299
# CAL 6	5		5.1276		0.1276		0.000651	0.000130
# CAL 7	5		11.0707		6.0707		1.474136	0.294827
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.360481
# RSE = 100 * √(0.360481) = 60.040%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# 13C2-6:2FTS (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		3.2275		-1.7725		0.125670	0.031418
# CAL 2	5		3.6542		-1.3458		0.072447	0.018112
# CAL 3	5		3.8056		-1.1944		0.057064	0.014266
# CAL 4	5		3.9283		-1.0717		0.045942	0.011485
# CAL 5	5		4.1861		-0.8139		0.026497	0.006624
# CAL 6	5		5.1276		0.1276		0.000651	0.000163
# CAL 7	5		11.0707		6.0707		1.474136	0.368534
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.450602
# RSE = 100 * √(0.450602) = 67.127%
#
# 13C8-PFOA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.6732		0.1732		0.004800	0.000960
# CAL 2	2.5		2.4140		-0.0860		0.001183	0.000237
# CAL 3	2.5		2.5576		0.0576		0.000531	0.000106
# CAL 4	2.5		2.4730		-0.0270		0.000117	0.000023
# CAL 5	2.5		2.4676		-0.0324		0.000168	0.000034
# CAL 6	2.5		2.4892		-0.0108		0.000019	0.000004
# CAL 7	2.5		2.4253		-0.0747		0.000893	0.000179
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.001542
# RSE = 100 * √(0.001542) = 3.927%
#
# 13C3-PFHxS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.5282		0.0282		0.000127	0.000025
# CAL 2	2.5		2.5439		0.0439		0.000308	0.000062
# CAL 3	2.5		2.4817		-0.0183		0.000054	0.000011
# CAL 4	2.5		2.4799		-0.0201		0.000065	0.000013
# CAL 5	2.5		2.4920		-0.0080		0.000010	0.000002
# CAL 6	2.5		2.5585		0.0585		0.000548	0.000110
# CAL 7	2.5		2.4158		-0.0842		0.001134	0.000227
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.000449
# RSE = 100 * √(0.000449) = 2.119%
# Warning: No expected concentrations provided for 13C9-PFNA
#
# 13C2-8:2FTS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		3.8406		-1.1594		0.053768	0.010754
# CAL 2	5		3.6447		-1.3553		0.073474	0.014695
# CAL 3	5		3.7973		-1.2027		0.057859	0.011572
# CAL 4	5		3.9398		-1.0602		0.044961	0.008992
# CAL 5	5		4.2115		-0.7885		0.024869	0.004974
# CAL 6	5		5.4604		0.4604		0.008479	0.001696
# CAL 7	5		10.1057		5.1057		1.042727	0.208545
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.261227
# RSE = 100 * √(0.261227) = 51.110%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# 13C2-8:2FTS (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		3.8406		-1.1594		0.053768	0.013442
# CAL 2	5		3.6447		-1.3553		0.073474	0.018368
# CAL 3	5		3.7973		-1.2027		0.057859	0.014465
# CAL 4	5		3.9398		-1.0602		0.044961	0.011240
# CAL 5	5		4.2115		-0.7885		0.024869	0.006217
# CAL 6	5		5.4604		0.4604		0.008479	0.002120
# CAL 7	5		10.1057		5.1057		1.042727	0.260682
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.326534
# RSE = 100 * √(0.326534) = 57.143%
#
# 13C6-PFDA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	1.25		1.2928		0.0428		0.001172	0.000234
# CAL 2	1.25		1.2710		0.0210		0.000282	0.000056
# CAL 3	1.25		1.2377		-0.0123		0.000097	0.000019
# CAL 4	1.25		1.2300		-0.0200		0.000256	0.000051
# CAL 5	1.25		1.2440		-0.0060		0.000023	0.000005
# CAL 6	1.25		1.3608		0.1108		0.007857	0.001571
# CAL 7	1.25		1.1137		-0.1363		0.011890	0.002378
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004315
# RSE = 100 * √(0.004315) = 6.569%
#
# D3-NMeFOSAA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		4.7882		-0.2118		0.001794	0.000359
# CAL 2	5		5.0156		0.0156		0.000010	0.000002
# CAL 3	5		4.7580		-0.2420		0.002343	0.000469
# CAL 4	5		4.8913		-0.1087		0.000473	0.000095
# CAL 5	5		5.0186		0.0186		0.000014	0.000003
# CAL 6	5		5.0491		0.0491		0.000096	0.000019
# CAL 7	5		5.4791		0.4791		0.009181	0.001836
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.002782
# RSE = 100 * √(0.002782) = 5.275%
#
# 13C8-PFOS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.4610		-0.0390		0.000243	0.000049
# CAL 2	2.5		2.5881		0.0881		0.001242	0.000248
# CAL 3	2.5		2.5079		0.0079		0.000010	0.000002
# CAL 4	2.5		2.5035		0.0035		0.000002	0.000000
# CAL 5	2.5		2.4483		-0.0517		0.000428	0.000086
# CAL 6	2.5		2.5145		0.0145		0.000034	0.000007
# CAL 7	2.5		2.4766		-0.0234		0.000088	0.000018
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.000409
# RSE = 100 * √(0.000409) = 2.023%
#
# D5-NEtFOSAA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	5		4.5997		-0.4003		0.006410	0.001282
# CAL 2	5		5.1029		0.1029		0.000424	0.000085
# CAL 3	5		4.5985		-0.4015		0.006448	0.001290
# CAL 4	5		5.1461		0.1461		0.000854	0.000171
# CAL 5	5		5.0322		0.0322		0.000041	0.000008
# CAL 6	5		4.8817		-0.1183		0.000560	0.000112
# CAL 7	5		5.6389		0.6389		0.016328	0.003266
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.006213
# RSE = 100 * √(0.006213) = 7.882%
#
# 13C7-PFUnA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	1.25		1.3191		0.0691		0.003056	0.000611
# CAL 2	1.25		1.2813		0.0313		0.000627	0.000125
# CAL 3	1.25		1.1849		-0.0651		0.002712	0.000542
# CAL 4	1.25		1.2358		-0.0142		0.000129	0.000026
# CAL 5	1.25		1.2374		-0.0126		0.000102	0.000020
# CAL 6	1.25		1.3606		0.1106		0.007829	0.001566
# CAL 7	1.25		1.1309		-0.1191		0.009078	0.001816
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004707
# RSE = 100 * √(0.004707) = 6.860%
#
# 13C2-PFDoA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	1.25		1.2901		0.0401		0.001029	0.000206
# CAL 2	1.25		1.2647		0.0147		0.000138	0.000028
# CAL 3	1.25		1.2165		-0.0335		0.000718	0.000144
# CAL 4	1.25		1.2674		0.0174		0.000194	0.000039
# CAL 5	1.25		1.2205		-0.0295		0.000557	0.000111
# CAL 6	1.25		1.3565		0.1065		0.007259	0.001452
# CAL 7	1.25		1.1342		-0.1158		0.008582	0.001716
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.003696
# RSE = 100 * √(0.003696) = 6.079%
#
# 13C2-PFTeDA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	1.25		1.2564		0.0064		0.000026	0.000005
# CAL 2	1.25		1.2164		-0.0336		0.000723	0.000145
# CAL 3	1.25		1.2021		-0.0479		0.001468	0.000294
# CAL 4	1.25		1.2061		-0.0439		0.001233	0.000247
# CAL 5	1.25		1.2068		-0.0432		0.001194	0.000239
# CAL 6	1.25		1.4078		0.1578		0.015937	0.003187
# CAL 7	1.25		1.2543		0.0043		0.000012	0.000002
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004119
# RSE = 100 * √(0.004119) = 6.418%
#
# 13C8-PFOSA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.4168		-0.0832		0.001108	0.000222
# CAL 2	2.5		2.4761		-0.0239		0.000091	0.000018
# CAL 3	2.5		2.4282		-0.0718		0.000825	0.000165
# CAL 4	2.5		2.4858		-0.0142		0.000032	0.000006
# CAL 5	2.5		2.3973		-0.1027		0.001688	0.000338
# CAL 6	2.5		2.4726		-0.0274		0.000120	0.000024
# CAL 7	2.5		2.8233		0.3233		0.016724	0.003345
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004117
# RSE = 100 * √(0.004117) = 6.417%
#
# D7-NMeFOSE (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	25		28.3246		3.3246		0.017685	0.003537
# CAL 2	25		24.6967		-0.3033		0.000147	0.000029
# CAL 3	25		24.3267		-0.6733		0.000725	0.000145
# CAL 4	25		24.5811		-0.4189		0.000281	0.000056
# CAL 5	25		23.8967		-1.1033		0.001948	0.000390
# CAL 6	25		24.2268		-0.7732		0.000957	0.000191
# CAL 7	25		24.9473		-0.0527		0.000004	0.000001
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004349
# RSE = 100 * √(0.004349) = 6.595%
#
# D3-NMeFOSA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.5426		0.0426		0.000290	0.000058
# CAL 2	2.5		2.4766		-0.0234		0.000088	0.000018
# CAL 3	2.5		2.3853		-0.1147		0.002105	0.000421
# CAL 4	2.5		2.4677		-0.0323		0.000167	0.000033
# CAL 5	2.5		2.3842		-0.1158		0.002146	0.000429
# CAL 6	2.5		2.4270		-0.0730		0.000853	0.000171
# CAL 7	2.5		2.8165		0.3165		0.016028	0.003206
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.004335
# RSE = 100 * √(0.004335) = 6.584%
#
# D9-NEtFOSE (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	25		29.2829		4.2829		0.029349	0.005870
# CAL 2	25		25.3933		0.3933		0.000247	0.000049
# CAL 3	25		24.5796		-0.4204		0.000283	0.000057
# CAL 4	25		25.0081		0.0081		0.000000	0.000000
# CAL 5	25		24.0501		-0.9499		0.001444	0.000289
# CAL 6	25		23.9794		-1.0206		0.001667	0.000333
# CAL 7	25		22.7067		-2.2933		0.008415	0.001683
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.008281
# RSE = 100 * √(0.008281) = 9.100%
#
# D5-NEtFOSA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.5		2.5911		0.0911		0.001328	0.000266
# CAL 2	2.5		2.4852		-0.0148		0.000035	0.000007
# CAL 3	2.5		2.4455		-0.0545		0.000475	0.000095
# CAL 4	2.5		2.5165		0.0165		0.000044	0.000009
# CAL 5	2.5		2.4671		-0.0329		0.000173	0.000035
# CAL 6	2.5		2.3678		-0.1322		0.002796	0.000559
# CAL 7	2.5		2.6267		0.1267		0.002568	0.000514
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.001484
# RSE = 100 * √(0.001484) = 3.852%
# Identified target analytes: ['PFBA', 'PFPeA', '4:2 FTS', 'PFHxA', 'PFBS', 'HFPO-DA', 'PFPeS', 'ADONA', '6:2 FTS', 'PFOA', 'PFHxS', 'PFNA', 'PFHpS', '8:2 FTS', 'PFDA', 'NMeFOSAA', 'PFOS', 'NEtFOSAA', 'PFUnA', '9Cl-PF3ONS', 'PFDoA', 'PFTrDA', 'PFTeDA', 'PFOSA', 'NMeFOSE', 'NMeFOSA', 'NEtFOSA', 'NEtFOSE']
#
# PFBA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.6675		-0.1325		0.027432	0.005486
# CAL 2	2.0		1.9208		-0.0792		0.001568	0.000314
# CAL 3	5.0		4.3186		-0.6814		0.018572	0.003714
# CAL 4	10.0		9.1347		-0.8653		0.007487	0.001497
# CAL 5	20.0		17.5725		-2.4275		0.014732	0.002946
# CAL 6	50.0		51.2175		1.2175		0.000593	0.000119
# CAL 7	250.0		227.3220		-22.6780		0.008229	0.001646
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.015723
# RSE = 100 * √(0.015723) = 12.539%
#
# PFPeA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.4		0.3699		-0.0301		0.005663	0.001133
# CAL 2	1.0		1.0420		0.0420		0.001764	0.000353
# CAL 3	2.5		2.3498		-0.1502		0.003610	0.000722
# CAL 4	5.0		5.0425		0.0425		0.000072	0.000014
# CAL 5	10.0		9.6631		-0.3369		0.001135	0.000227
# CAL 6	25.0		28.3622		3.3622		0.018087	0.003617
# CAL 7	125.0		124.3286		-0.6714		0.000029	0.000006
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.006072
# RSE = 100 * √(0.006072) = 7.792%
#
# 4:2 FTS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.7993		-0.0007		0.000001	0.000000
# CAL 2	2.0		2.3023		0.3023		0.022846	0.004569
# CAL 3	5.0		5.2810		0.2810		0.003158	0.000632
# CAL 4	10.0		10.7798		0.7798		0.006081	0.001216
# CAL 5	20.0		19.4519		-0.5481		0.000751	0.000150
# CAL 6	50.0		46.2764		-3.7236		0.005546	0.001109
# CAL 7	250.0		111.7311		-138.2689		0.305893	0.061179
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.068855
# RSE = 100 * √(0.068855) = 26.240%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# 4:2 FTS (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.7993		-0.0007		0.000001	0.000000
# CAL 2	2.0		2.3023		0.3023		0.022846	0.005712
# CAL 3	5.0		5.2810		0.2810		0.003158	0.000790
# CAL 4	10.0		10.7798		0.7798		0.006081	0.001520
# CAL 5	20.0		19.4519		-0.5481		0.000751	0.000188
# CAL 6	50.0		46.2764		-3.7236		0.005546	0.001387
# CAL 7	250.0		111.7311		-138.2689		0.305893	0.076473
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.086069
# RSE = 100 * √(0.086069) = 29.338%
#
# PFHxA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1754		-0.0246		0.015129	0.003026
# CAL 2	0.5		0.4679		-0.0321		0.004122	0.000824
# CAL 3	1.25		1.0667		-0.1833		0.021503	0.004301
# CAL 4	2.5		2.2736		-0.2264		0.008201	0.001640
# CAL 5	5.0		4.3568		-0.6432		0.016548	0.003310
# CAL 6	12.5		12.8226		0.3226		0.000666	0.000133
# CAL 7	62.5		56.6717		-5.8283		0.008696	0.001739
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.014973
# RSE = 100 * √(0.014973) = 12.236%
#
# PFBS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1751		-0.0249		0.015500	0.003100
# CAL 2	0.5		0.5023		0.0023		0.000021	0.000004
# CAL 3	1.25		1.1681		-0.0819		0.004293	0.000859
# CAL 4	2.5		2.3261		-0.1739		0.004839	0.000968
# CAL 5	5.0		4.3776		-0.6224		0.015495	0.003099
# CAL 6	12.5		12.8482		0.3482		0.000776	0.000155
# CAL 7	62.5		62.4885		-0.0115		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.008185
# RSE = 100 * √(0.008185) = 9.047%
#
# HFPO-DA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.6589		-0.1411		0.031108	0.006222
# CAL 2	2.0		1.9182		-0.0818		0.001673	0.000335
# CAL 3	5.0		4.1887		-0.8113		0.026328	0.005266
# CAL 4	10.0		9.6717		-0.3283		0.001078	0.000216
# CAL 5	20.0		17.7911		-2.2089		0.012198	0.002440
# CAL 6	50.0		51.2485		1.2485		0.000624	0.000125
# CAL 7	250.0		249.9551		-0.0449		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.014602
# RSE = 100 * √(0.014602) = 12.084%
#
# PFPeS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1619		-0.0381		0.036290	0.007258
# CAL 2	0.5		0.4872		-0.0128		0.000655	0.000131
# CAL 3	1.25		1.1193		-0.1307		0.010933	0.002187
# CAL 4	2.5		2.3067		-0.1933		0.005978	0.001196
# CAL 5	5.0		4.5038		-0.4962		0.009849	0.001970
# CAL 6	12.5		12.5691		0.0691		0.000031	0.000006
# CAL 7	62.5		62.4961		-0.0039		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.012747
# RSE = 100 * √(0.012747) = 11.290%
#
# ADONA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.6589		-0.1411		0.031108	0.006222
# CAL 2	2.0		1.8615		-0.1385		0.004796	0.000959
# CAL 3	5.0		4.1316		-0.8684		0.030165	0.006033
# CAL 4	10.0		9.1593		-0.8407		0.007068	0.001414
# CAL 5	20.0		17.4624		-2.5376		0.016099	0.003220
# CAL 6	50.0		50.3336		0.3336		0.000045	0.000009
# CAL 7	250.0		249.9849		-0.0151		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.017856
# RSE = 100 * √(0.017856) = 13.363%
#
# 6:2 FTS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.9166		0.1166		0.021243	0.004249
# CAL 2	2.0		2.1594		0.1594		0.006352	0.001270
# CAL 3	5.0		5.1702		0.1702		0.001159	0.000232
# CAL 4	10.0		10.6300		0.6300		0.003969	0.000794
# CAL 5	20.0		19.5783		-0.4217		0.000445	0.000089
# CAL 6	50.0		49.0632		-0.9368		0.000351	0.000070
# CAL 7	250.0		118.3170		-131.6830		0.277447	0.055489
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.062193
# RSE = 100 * √(0.062193) = 24.939%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# 6:2 FTS (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.9166		0.1166		0.021243	0.005311
# CAL 2	2.0		2.1594		0.1594		0.006352	0.001588
# CAL 3	5.0		5.1702		0.1702		0.001159	0.000290
# CAL 4	10.0		10.6300		0.6300		0.003969	0.000992
# CAL 5	20.0		19.5783		-0.4217		0.000445	0.000111
# CAL 6	50.0		49.0632		-0.9368		0.000351	0.000088
# CAL 7	250.0		118.3170		-131.6830		0.277447	0.069362
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.077741
# RSE = 100 * √(0.077741) = 27.882%
#
# PFOA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1666		-0.0334		0.027889	0.005578
# CAL 2	0.5		0.4782		-0.0218		0.001901	0.000380
# CAL 3	1.25		1.0812		-0.1688		0.018236	0.003647
# CAL 4	2.5		2.3444		-0.1556		0.003874	0.000775
# CAL 5	5.0		4.4507		-0.5493		0.012069	0.002414
# CAL 6	12.5		12.7691		0.2691		0.000463	0.000093
# CAL 7	62.5		56.7025		-5.7975		0.008604	0.001721
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.014607
# RSE = 100 * √(0.014607) = 12.086%
#
# PFHxS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1697		-0.0303		0.022952	0.004590
# CAL 2	0.5		0.4484		-0.0516		0.010650	0.002130
# CAL 3	1.25		1.1117		-0.1383		0.012241	0.002448
# CAL 4	2.5		2.3827		-0.1173		0.002201	0.000440
# CAL 5	5.0		4.4981		-0.5019		0.010076	0.002015
# CAL 6	12.5		12.7406		0.2406		0.000370	0.000074
# CAL 7	62.5		60.2054		-2.2946		0.001348	0.000270
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.011968
# RSE = 100 * √(0.011968) = 10.940%
#
# PFNA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1725		-0.0275		0.018906	0.003781
# CAL 2	0.5		0.4815		-0.0185		0.001369	0.000274
# CAL 3	1.25		1.1215		-0.1285		0.010568	0.002114
# CAL 4	2.5		2.3178		-0.1822		0.005311	0.001062
# CAL 5	5.0		4.4256		-0.5744		0.013197	0.002639
# CAL 6	12.5		12.7802		0.2802		0.000502	0.000100
# CAL 7	62.5		59.1952		-3.3048		0.002796	0.000559
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.010530
# RSE = 100 * √(0.010530) = 10.262%
#
# PFHpS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.2003		0.0003		0.000002	0.000000
# CAL 2	0.5		0.5687		0.0687		0.018879	0.003776
# CAL 3	1.25		1.2346		-0.0154		0.000152	0.000030
# CAL 4	2.5		2.8158		0.3158		0.015957	0.003191
# CAL 5	5.0		5.1485		0.1485		0.000882	0.000176
# CAL 6	12.5		14.5898		2.0898		0.027950	0.005590
# CAL 7	62.5		62.0692		-0.4308		0.000048	0.000010
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.012774
# RSE = 100 * √(0.012774) = 11.302%
#
# 8:2 FTS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.7059		-0.0941		0.013836	0.002767
# CAL 2	2.0		2.3514		0.3514		0.030870	0.006174
# CAL 3	5.0		5.3006		0.3006		0.003614	0.000723
# CAL 4	10.0		11.1390		1.1390		0.012973	0.002595
# CAL 5	20.0		19.2454		-0.7546		0.001424	0.000285
# CAL 6	50.0		43.2057		-6.7943		0.018465	0.003693
# CAL 7	250.0		95.8817		-154.1183		0.380039	0.076008
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.092244
# RSE = 100 * √(0.092244) = 30.372%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# 8:2 FTS (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.7059		-0.0941		0.013836	0.003459
# CAL 2	2.0		2.3514		0.3514		0.030870	0.007718
# CAL 3	5.0		5.3006		0.3006		0.003614	0.000904
# CAL 4	10.0		11.1390		1.1390		0.012973	0.003243
# CAL 5	20.0		19.2454		-0.7546		0.001424	0.000356
# CAL 6	50.0		43.2057		-6.7943		0.018465	0.004616
# CAL 7	250.0		95.8817		-154.1183		0.380039	0.095010
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.115305
# RSE = 100 * √(0.115305) = 33.957%
#
# PFDA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1603		-0.0397		0.039402	0.007880
# CAL 2	0.5		0.4978		-0.0022		0.000019	0.000004
# CAL 3	1.25		1.0520		-0.1980		0.025091	0.005018
# CAL 4	2.5		2.2865		-0.2135		0.007293	0.001459
# CAL 5	5.0		4.3197		-0.6803		0.018512	0.003702
# CAL 6	12.5		12.8353		0.3353		0.000720	0.000144
# CAL 7	62.5		57.7198		-4.7802		0.005850	0.001170
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.019377
# RSE = 100 * √(0.019377) = 13.920%
#
# NMeFOSAA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1687		-0.0313		0.024492	0.004898
# CAL 2	0.5		0.4986		-0.0014		0.000008	0.000002
# CAL 3	1.25		1.0279		-0.2221		0.031570	0.006314
# CAL 4	2.5		2.2291		-0.2709		0.011742	0.002348
# CAL 5	5.0		3.4515		-1.5485		0.095914	0.019183
# CAL 6	12.5		12.6052		0.1052		0.000071	0.000014
# CAL 7	62.5		62.4903		-0.0097		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.032759
# RSE = 100 * √(0.032759) = 18.100%
#
# PFOS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1733		-0.0267		0.017822	0.003564
# CAL 2	0.5		0.5191		0.0191		0.001459	0.000292
# CAL 3	1.25		1.1353		-0.1147		0.008420	0.001684
# CAL 4	2.5		2.3428		-0.1572		0.003954	0.000791
# CAL 5	5.0		4.4939		-0.5061		0.010245	0.002049
# CAL 6	12.5		12.7450		0.2450		0.000384	0.000077
# CAL 7	62.5		59.2079		-3.2921		0.002775	0.000555
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.009012
# RSE = 100 * √(0.009012) = 9.493%
#
# NEtFOSAA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1605		-0.0395		0.039006	0.007801
# CAL 2	0.5		0.3874		-0.1126		0.050715	0.010143
# CAL 3	1.25		0.8505		-0.3995		0.102144	0.020429
# CAL 4	2.5		1.7596		-0.7404		0.087711	0.017542
# CAL 5	5.0		3.9390		-1.0610		0.045029	0.009006
# CAL 6	12.5		12.7513		0.2513		0.000404	0.000081
# CAL 7	62.5		62.4865		-0.0135		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.065002
# RSE = 100 * √(0.065002) = 25.495%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# NEtFOSAA (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1605		-0.0395		0.039006	0.009752
# CAL 2	0.5		0.3874		-0.1126		0.050715	0.012679
# CAL 3	1.25		0.8505		-0.3995		0.102144	0.025536
# CAL 4	2.5		1.7596		-0.7404		0.087711	0.021928
# CAL 5	5.0		3.9390		-1.0610		0.045029	0.011257
# CAL 6	12.5		12.7513		0.2513		0.000404	0.000101
# CAL 7	62.5		62.4865		-0.0135		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.081252
# RSE = 100 * √(0.081252) = 28.505%
#
# PFUnA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1749		-0.0251		0.015750	0.003150
# CAL 2	0.5		0.4980		-0.0020		0.000016	0.000003
# CAL 3	1.25		1.1747		-0.0753		0.003629	0.000726
# CAL 4	2.5		2.4868		-0.0132		0.000028	0.000006
# CAL 5	5.0		4.8842		-0.1158		0.000536	0.000107
# CAL 6	12.5		13.9209		1.4209		0.012921	0.002584
# CAL 7	62.5		62.2179		-0.2821		0.000020	0.000004
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.006580
# RSE = 100 * √(0.006580) = 8.112%
#
# 9Cl-PF3ONS (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.8		0.7250		-0.0750		0.008789	0.001758
# CAL 2	2.0		2.0143		0.0143		0.000051	0.000010
# CAL 3	5.0		4.4511		-0.5489		0.012052	0.002410
# CAL 4	10.0		9.7897		-0.2103		0.000442	0.000088
# CAL 5	20.0		17.9082		-2.0918		0.010939	0.002188
# CAL 6	50.0		50.1266		0.1266		0.000006	0.000001
# CAL 7	250.0		249.9934		-0.0066		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.006456
# RSE = 100 * √(0.006456) = 8.035%
#
# PFDoA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1682		-0.0318		0.025281	0.005056
# CAL 2	0.5		0.4598		-0.0402		0.006464	0.001293
# CAL 3	1.25		1.1067		-0.1433		0.013142	0.002628
# CAL 4	2.5		2.2460		-0.2540		0.010323	0.002065
# CAL 5	5.0		4.5016		-0.4984		0.009936	0.001987
# CAL 6	12.5		12.8209		0.3209		0.000659	0.000132
# CAL 7	62.5		62.4887		-0.0113		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.013161
# RSE = 100 * √(0.013161) = 11.472%
#
# PFTrDA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1671		-0.0329		0.027060	0.005412
# CAL 2	0.5		0.4857		-0.0143		0.000818	0.000164
# CAL 3	1.25		1.0430		-0.2070		0.027423	0.005485
# CAL 4	2.5		2.2825		-0.2175		0.007569	0.001514
# CAL 5	5.0		4.4594		-0.5406		0.011690	0.002338
# CAL 6	12.5		12.8474		0.3474		0.000772	0.000154
# CAL 7	62.5		62.4850		-0.0150		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.015067
# RSE = 100 * √(0.015067) = 12.275%
#
# PFTeDA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1617		-0.0383		0.036672	0.007334
# CAL 2	0.5		0.4856		-0.0144		0.000829	0.000166
# CAL 3	1.25		1.0132		-0.2368		0.035888	0.007178
# CAL 4	2.5		2.1969		-0.3031		0.014699	0.002940
# CAL 5	5.0		4.2164		-0.7836		0.024561	0.004912
# CAL 6	12.5		12.6104		0.1104		0.000078	0.000016
# CAL 7	62.5		62.4943		-0.0057		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.022546
# RSE = 100 * √(0.022546) = 15.015%
#
# PFOSA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1930		-0.0070		0.001225	0.000245
# CAL 2	0.5		0.5336		0.0336		0.004516	0.000903
# CAL 3	1.25		1.1854		-0.0646		0.002671	0.000534
# CAL 4	2.5		2.4993		-0.0007		0.000000	0.000000
# CAL 5	5.0		4.8881		-0.1119		0.000501	0.000100
# CAL 6	12.5		14.1381		1.6381		0.017174	0.003435
# CAL 7	62.5		62.1734		-0.3266		0.000027	0.000005
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.005223
# RSE = 100 * √(0.005223) = 7.227%
#
# NMeFOSE (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.0		5.6692		3.6692		3.365757	0.673151
# CAL 2	5.0		16.6274		11.6274		5.407857	1.081571
# CAL 3	12.5		36.2019		23.7019		3.595392	0.719078
# CAL 4	25.0		68.5892		43.5892		3.040029	0.608006
# CAL 5	50.0		115.1006		65.1006		1.695235	0.339047
# CAL 6	25.0		251.5581		226.5581		82.125716	16.425143
# CAL 7	625.0		625.1182		0.1182		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 19.845998
# RSE = 100 * √(19.845998) = 445.488%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# NMeFOSE (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.0		5.6692		3.6692		3.365757	0.841439
# CAL 2	5.0		16.6274		11.6274		5.407857	1.351964
# CAL 3	12.5		36.2019		23.7019		3.595392	0.898848
# CAL 4	25.0		68.5892		43.5892		3.040029	0.760007
# CAL 5	50.0		115.1006		65.1006		1.695235	0.423809
# CAL 6	25.0		251.5581		226.5581		82.125716	20.531429
# CAL 7	625.0		625.1182		0.1182		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 24.807497
# RSE = 100 * √(24.807497) = 498.071%
#
# NMeFOSA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1574		-0.0426		0.045369	0.009074
# CAL 2	0.5		0.4692		-0.0308		0.003795	0.000759
# CAL 3	1.25		1.0609		-0.1891		0.022886	0.004577
# CAL 4	2.5		2.2782		-0.2218		0.007871	0.001574
# CAL 5	5.0		4.2782		-0.7218		0.020840	0.004168
# CAL 6	12.5		12.5849		0.0849		0.000046	0.000009
# CAL 7	62.5		62.4953		-0.0047		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.020161
# RSE = 100 * √(0.020161) = 14.199%
#
# NEtFOSA (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	0.2		0.1670		-0.0330		0.027225	0.005445
# CAL 2	0.5		0.4037		-0.0963		0.037095	0.007419
# CAL 3	1.25		1.0091		-0.2409		0.037141	0.007428
# CAL 4	2.5		2.0988		-0.4012		0.025754	0.005151
# CAL 5	5.0		3.9957		-1.0043		0.040345	0.008069
# CAL 6	12.5		12.6382		0.1382		0.000122	0.000024
# CAL 7	62.5		62.4937		-0.0063		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 0.033536
# RSE = 100 * √(0.033536) = 18.313%
#
# NEtFOSE (p=2)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.0		6.1440		4.1440		4.293184	0.858637
# CAL 2	5.0		16.1474		11.1474		4.970581	0.994116
# CAL 3	12.5		34.4188		21.9188		3.074776	0.614955
# CAL 4	25.0		67.1198		42.1198		2.838524	0.567705
# CAL 5	50.0		115.4462		65.4462		1.713282	0.342656
# CAL 6	25.0		248.5008		223.5008		79.924172	15.984834
# CAL 7	625.0		625.1161		0.1161		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 19.362904
# RSE = 100 * √(19.362904) = 440.033%
#
# Linearity test failed (RSE > 20%), recalculating with p=3 (quadratic)...
#
# NEtFOSE (p=3)
# ============================================================
# Point	Expected	Measured	Difference	(Diff)²/xi²	(Diff)²/xi²/(n-p)
# --------------------------------------------------------------------------------
# CAL 1	2.0		6.1440		4.1440		4.293184	1.073296
# CAL 2	5.0		16.1474		11.1474		4.970581	1.242645
# CAL 3	12.5		34.4188		21.9188		3.074776	0.768694
# CAL 4	25.0		67.1198		42.1198		2.838524	0.709631
# CAL 5	50.0		115.4462		65.4462		1.713282	0.428321
# CAL 6	25.0		248.5008		223.5008		79.924172	19.981043
# CAL 7	625.0		625.1161		0.1161		0.000000	0.000000
# --------------------------------------------------------------------------------
# Sum of relative squared errors: 24.203630
# RSE = 100 * √(24.203630) = 491.972%
#
# ============================================================
# COMPOUND RSE SUMMARY
# ============================================================
#
# 13C4-PFBA:
#   RSE: 0.425%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C5-PFPeA:
#   RSE: 2.470%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C2-4:2FTS:
#   RSE: 71.998%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# 13C5-PFHxA:
#   RSE: 0.456%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C3-PFBS:
#   RSE: 6.008%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C3-HFPO-DA:
#   RSE: 6.369%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C2-6:2FTS:
#   RSE: 67.127%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# 13C8-PFOA:
#   RSE: 3.927%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C3-PFHxS:
#   RSE: 2.119%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C2-8:2FTS:
#   RSE: 57.143%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# 13C6-PFDA:
#   RSE: 6.569%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# D3-NMeFOSAA:
#   RSE: 5.275%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C8-PFOS:
#   RSE: 2.023%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# D5-NEtFOSAA:
#   RSE: 7.882%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C7-PFUnA:
#   RSE: 6.860%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C2-PFDoA:
#   RSE: 6.079%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C2-PFTeDA:
#   RSE: 6.418%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 13C8-PFOSA:
#   RSE: 6.417%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# D7-NMeFOSE:
#   RSE: 6.595%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# D3-NMeFOSA:
#   RSE: 6.584%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# D9-NEtFOSE:
#   RSE: 9.100%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# D5-NEtFOSA:
#   RSE: 3.852%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# ============================================================
# COMPOUND RSE SUMMARY
# ============================================================
#
# PFBA:
#   RSE: 12.539%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFPeA:
#   RSE: 7.792%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 4:2 FTS:
#   RSE: 29.338%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# PFHxA:
#   RSE: 12.236%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFBS:
#   RSE: 9.047%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# HFPO-DA:
#   RSE: 12.084%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFPeS:
#   RSE: 11.290%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# ADONA:
#   RSE: 13.363%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 6:2 FTS:
#   RSE: 27.882%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# PFOA:
#   RSE: 12.086%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFHxS:
#   RSE: 10.940%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFNA:
#   RSE: 10.262%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFHpS:
#   RSE: 11.302%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 8:2 FTS:
#   RSE: 33.957%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# PFDA:
#   RSE: 13.920%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# NMeFOSAA:
#   RSE: 18.100%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFOS:
#   RSE: 9.493%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# NEtFOSAA:
#   RSE: 28.505%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# PFUnA:
#   RSE: 8.112%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# 9Cl-PF3ONS:
#   RSE: 8.035%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFDoA:
#   RSE: 11.472%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFTrDA:
#   RSE: 12.275%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFTeDA:
#   RSE: 15.015%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# PFOSA:
#   RSE: 7.227%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# NMeFOSE:
#   RSE: 498.071%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
#
# NMeFOSA:
#   RSE: 14.199%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# NEtFOSA:
#   RSE: 18.313%
#   Calibration Points: 7
#   Relationship type: linear (p = 2)
#
# NEtFOSE:
#   RSE: 491.972%
#   Calibration Points: 7
#   Relationship type: quadratic (p = 3)
#   ⚠ WARNING: Even after quadratic fit (p=3), RSE > 20% — system does not pass linearity or quadratic check.
